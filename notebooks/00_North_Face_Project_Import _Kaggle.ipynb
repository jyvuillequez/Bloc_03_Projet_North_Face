# %%
import pandas as pd
import os
import kagglehub

# %%
path = kagglehub.dataset_download("cclark/product-item-data")

print("Path to dataset files:", path)
print(os.listdir(path))
# Out:
# ...
# Path to dataset files: C:\Users\jean-\.cache\kagglehub\datasets\cclark\product-item-data\versions\1
# ['sample-data.csv']

# %%
df = pd.read_csv(os.path.join(path, "sample-data.csv"))
df.head()
# Out:
#    id                                        description
# 0   1  Active classic boxers - There's a reason why o...
# 1   2  Active sport boxer briefs - Skinning up Glory ...
# 2   3  Active sport briefs - These superbreathable no...
# 3   4  Alpine guide pants - Skin in, climb ice, switc...
# 4   5  Alpine wind jkt - On high ridges, steep ice an...

# %%
df.to_csv("../data/raw/sample-data-export.csv", index=False)
